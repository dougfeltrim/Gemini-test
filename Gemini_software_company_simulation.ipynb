# %% [markdown]
# <a href="https://colab.research.google.com/github/dougfeltrim/Gemini-test/blob/main/Gemini_software.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# prompt: Gere uma empresa de software usando agentes, preciso que ao final consiga gerar um projeto completo e pronto para o cliente, no final preciso que imprima o codigo final e sua documentacao

import os
from google.colab import userdata
from google import genai
from google.genai import types

os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# Remove the explicit api_key argument to use the environment variable
client = genai.Client()

class Agent:
    def __init__(self, name, system_instruction):
        self.name = name
        self.system_instruction = system_instruction
        self.history = []

    def generate_response(self, prompt):
        response = client.models.generate_content(
            model="gemini-2.0-flash",
            config=types.GenerateContentConfig(
                system_instruction=self.system_instruction,
                max_output_tokens=1024,
                temperature=0.7 # Lower temperature for more focused responses
            ),
            contents=prompt
        )
        self.history.append({"prompt": prompt, "response": response.text})
        return response.text

class SoftwareCompany:
    def __init__(self):
        self.agents = {
            "Product Manager": Agent("Gerente de Produto", "Você define os requisitos do software e a visão do produto."),
            "Software Architect": Agent("Arquiteto de Software", "Você projeta a arquitetura do software e as tecnologias a serem usadas."),
            "Developer": Agent("Desenvolvedor", "Você escreve o código real do software."),
            "Technical Writer": Agent("Redator Técnico", "Você escreve a documentação do software."),
            "Project Synthesizer": Agent("Sintetizador de Projeto", "Você consolida o trabalho de todos os agentes em um projeto final. Crie o respitorio do projeto após a consolidaçao")
        }

    def generate_project(self, project_description, rounds=5):
        current_task = f"Crie um projeto de software baseado na seguinte descrição: {project_description}"
        project_components = {}

        for i in range(rounds):
            print(f"\n--- Rodada {i+1} ---")
            responses = {}
            for role, agent in self.agents.items():
                if role != "Project Synthesizer": # Synthesizer acts last
                    print(f"{agent.name} pensando sobre: {current_task}...")
                    response = agent.generate_response(current_task)
                    responses[role] = response
                    print(f"{agent.name}: {response}")

            # Synthesizer consolidates the work
            synthesis_prompt = "Consolide o seguinte trabalho para avançar no projeto:\n"
            for role, resp in responses.items():
                synthesis_prompt += f"Do {role}: {resp}\n"

            print("\nSintetizador de Projeto consolidando...")
            current_task = self.agents["Project Synthesizer"].generate_response(synthesis_prompt)
            print(f"Sintetizador de Projeto (Síntese): {current_task}")

            # Assuming in later rounds, agents start generating specific components
            # This is a simplified example; in a real scenario, you'd need more sophisticated parsing
            if i >= rounds - 2: # In the last two rounds, focus on generating code and documentation
                code_prompt = "Gere o código Python para o projeto baseado na tarefa atual:"
                code_response = self.agents["Developer"].generate_response(code_prompt + "\n" + current_task)
                project_components["code"] = code_response

                doc_prompt = "Gere a documentação técnica para o projeto baseado na tarefa atual e código gerado:"
                doc_response = self.agents["Technical Writer"].generate_response(doc_prompt + "\n" + current_task + "\nCódigo:\n" + code_response)
                project_components["documentation"] = doc_response


        # Final consolidation by the Project Synthesizer
        final_synthesis_prompt = "Com base em todo o trabalho realizado, gere o projeto final pronto para o cliente, incluindo código e documentação:\n"
        if "code" in project_components:
             final_synthesis_prompt += f"Código Gerado:\n{project_components['code']}\n"
        if "documentation" in project_components:
             final_synthesis_prompt += f"Documentação Gerada:\n{project_components['documentation']}\n"
        final_project_summary = self.agents["Project Synthesizer"].generate_response(final_synthesis_prompt)


        return project_components.get("code", "Não foi possível gerar o código."), project_components.get("documentation", "Não foi possível gerar a documentação.")

# Exemplo de uso da empresa de software
company = SoftwareCompany()
project_description = "Desenvolver um script de calculadora para ser executado no terminal"
final_code, final_documentation = company.generate_project(project_description, rounds=1) # More rounds for a more complete project
# Out:
# --- Rodada 1 ---
# Gerente de Produto pensando sobre: Crie um projeto de software baseado na seguinte descrição: Desenvolver um script de calculadora para ser executado no terminal...
# Gerente de Produto: ## Projeto de Software: Script de Calculadora para Terminal
#
# **1. Visão Geral:**
#
# Este projeto visa desenvolver um script de calculadora interativa que será executado no terminal. O script permitirá que os usuários realizem operações aritméticas básicas (adição, subtração, multiplicação, divisão) e, potencialmente, funções mais avançadas, diretamente da linha de comando. A calculadora será fácil de usar, intuitiva e fornecerá resultados precisos.
#
# **2. Objetivos:**
#
# *   **Funcionalidade:** Implementar as operações aritméticas básicas (adição, subtração, multiplicação, divisão).
# *   **Usabilidade:** Criar uma interface de usuário simples e intuitiva no terminal.
# *   **Precisão:** Garantir que os cálculos sejam realizados com precisão.
# *   **Robustez:** Lidar com entradas inválidas de forma graciosa e evitar erros.
# *   **Extensibilidade:** Projetar o script de forma que seja fácil adicionar novas funcionalidades no futuro.
# *   **Portabilidade:** Desenvolver o script de forma a ser compatível com diferentes sistemas operacionais (Windows, Linux, macOS) que suportem a linguagem de programação escolhida.
#
# **3. Requisitos Funcionais:**
#
# *   **Entrada do Usuário:**
#     *   O script deve solicitar ao usuário que insira uma expressão matemática.
#     *   O script deve permitir que o usuário insira números inteiros e decimais.
#     *   O script deve permitir que o usuário utilize os operadores aritméticos: `+`, `-`, `*`, `/`.
#     *   O script deve permitir que o usuário utilize parênteses `(` e `)` para agrupar operações.
#     *   O script deve permitir que o usuário utilize a tecla `Enter` para submeter a expressão.
#     *   O script deve permitir que o usuário saia do programa digitando um comando específico (ex: `sair`, `exit`, `q`).
# *   **Processamento:**
#     *   O script deve analisar a expressão inserida pelo usuário.
#     *   O script deve seguir a ordem de precedência dos operadores (parênteses, multiplicação e divisão, adição e subtração).
#     *   O script deve realizar os cálculos corretamente.
# *   **Saída:**
#     *   O script deve exibir o resultado do cálculo no terminal.
#     *   O script deve exibir mensagens de erro claras e informativas em caso de entrada inválida ou erros de cálculo (ex: divisão por zero).
#     *   O script deve exibir um prompt para que o usuário insira a próxima expressão.
# *   **Operações Suportadas (Mínimo):**
#     *   Adição (+)
#     *   Subtração (-)
#     *   Multiplicação (*)
#     *   Divisão (/)
# *   **Operações Suportadas (Opcional - para versões futuras):**
#     *   Exponenciação (^)
#     *   Raiz Quadrada (sqrt)
#     *   Funções trigonométricas (sin, cos, tan)
#     *   Logaritmo (log)
#     *   Porcentagem (%)
#
# **4. Requisitos Não Funcionais:**
#
# *   **Performance:** O script deve realizar os cálculos rapidamente (tempo de resposta aceitável).
# *   **Usabilidade:** A interface deve ser intuitiva e fácil de usar para usuários com conhecimento básico de matemática.
# *   **Manutenibilidade:** O código deve ser bem estruturado, comentado e fácil de entender para facilitar a manutenção e futuras modificações.
# *   **Portabilidade:** O script deve ser compatível com diferentes sistemas operacionais (Windows, Linux, macOS) que suportem a linguagem de programação escolhida.
# *   **Segurança:** O script deve ser seguro e evitar vulnerabilidades que possam ser exploradas.
#
# **5. Linguagem de Programação:**
#
# A linguagem de programação a ser utilizada será escolhida com base nos seguintes critérios:
#
# *   Facilidade de uso e aprendizado
# *   Disponibilidade de bibliotecas para manipulação de strings e cálculos matemáticos
# *   Portabilidade
# *   Popularidade e suporte da comunidade
#
# Possíveis linguagens:
#
# *   **Python:** Uma boa escolha devido à sua sintaxe clara, bibliotecas ricas e portabilidade.
# *   **JavaScript (Node.js):** Uma opção viável se o objetivo for também criar uma versão web da calculadora no futuro.
# *   **Bash Scripting:** Uma opção simples e rápida para sistemas Linux/macOS, mas pode ser menos flexível para funcionalidades mais avançadas.
#
# **6. Design da Interface do Usuário (Terminal):**
#
# A interface será baseada em texto e seguirá um padrão simples:
#
# ```
# Calculadora de Terminal
#
# Digite sua expressão (ou 'sair' para sair):
#
# > 1 + 2 * 3
#
# Arquiteto de Software pensando sobre: Crie um projeto de software baseado na seguinte descrição: Desenvolver um script de calculadora para ser executado no terminal...
# Arquiteto de Software: ## Projeto de Software: Calculadora de Terminal
#
# **1. Visão Geral:**
#
# Este projeto visa criar um script de calculadora executado diretamente no terminal, oferecendo funcionalidades básicas de aritmética (adição, subtração, multiplicação, divisão) e, opcionalmente, funcionalidades mais avançadas (potenciação, radiciação, logaritmos, funções trigonométricas). O script será interativo, solicitando ao usuário a entrada de números e operações, e exibindo o resultado no terminal.
#
# **2. Arquitetura:**
#
# A arquitetura do script será simples e modular, focada na legibilidade e manutenibilidade. Podemos dividi-la em:
#
# *   **Entrada (Input):** Responsável por receber a entrada do usuário (números e operações) e validá-la.
# *   **Processamento (Calculation):** Responsável por realizar os cálculos matemáticos com base na entrada do usuário.
# *   **Saída (Output):** Responsável por exibir o resultado do cálculo para o usuário no terminal.
# *   **Interface do Usuário (UI - Terminal):** Responsável por interagir com o usuário, apresentar as opções e exibir os resultados.
#
# **Diagrama Simplificado:**
#
# ```
# +---------------------+     +------------------------+     +---------------------+
# | Entrada (Input)     | --> | Processamento (Calculation)| --> | Saída (Output)     |
# |  - Obter dados      |     |  - Validar operações   |     |  - Exibir resultado  |
# |  - Validar dados    |     |  - Realizar cálculos    |     |                     |
# +---------------------+     +------------------------+     +---------------------+
#        ^                                                              |
#        |                                                              |
#        +---------------------+                                       |
#        | Interface do Usuário| <---------------------------------------
#        |  - Menu/Prompt      |
#        |  - Interação        |
#        +---------------------+
# ```
#
# **3. Tecnologias:**
#
# A escolha da linguagem de programação depende dos requisitos de desempenho, portabilidade e familiaridade da equipe. Algumas opções populares incluem:
#
# *   **Python:**  Excelente para prototipagem rápida, fácil de aprender, possui bibliotecas matemáticas poderosas (como `math` para funções avançadas) e é altamente portátil.  **Recomendado para a maioria dos casos.**
# *   **Bash Script:**  Ideal para scripts simples e rápidos, especialmente se a calculadora se limitar a operações básicas.  É universalmente disponível em sistemas Linux/macOS.
# *   **JavaScript (Node.js):** Permite executar o script no terminal usando Node.js. Útil se você já tem familiaridade com JavaScript e deseja usar suas bibliotecas.
# *   **C/C++:**  Oferece o melhor desempenho e controle, mas requer mais esforço de desenvolvimento.  Adequado para cenários onde a performance é crítica.
#
# **Neste projeto, assumiremos Python como a linguagem de programação devido à sua facilidade de uso e ampla gama de recursos.**
#
# **4. Módulos e Funções:**
#
# Dentro do script Python, podemos organizar o código em funções para melhorar a legibilidade e reutilização:
#
# *   `get_input()`:
#     *   Solicita ao usuário os números e a operação desejada.
#     *   Valida a entrada do usuário (ex: verifica se os números são válidos, se a operação é suportada).
#     *   Retorna os números e a operação como uma tupla ou lista.
# *   `calculate(num1, num2, operation)`:
#     *   Recebe dois números e a operação como entrada.
#     *   Realiza o cálculo com base na operação.
#     *   Lança uma exceção se a operação for inválida (ex: divisão por zero).
#     *   Retorna o resultado do cálculo.
# *   `display_result(result)`:
#     *   Recebe o resultado do cálculo como entrada.
#     *   Formata e exibe o resultado no terminal.
# *   `main()`:
#     *   Função principal que coordena todo o fluxo do programa.
#     *   Chama as funções `get_input()`, `calculate()`, e `display_result()`.
#     *   Implementa um loop para permitir que o usuário realize múltiplos cálculos.
#
# **5. Funcionalidades:**
#
# *   **Básicas:**
#     *   Adição (+): `num1 + num2`
#     *   Subtração (-): `num1 - num2`
#     *   Multiplicação (*): `num1 * num2`
#     *   Divisão (/): `num1 / num2` (Tratar divisão por zero)
# *   **Avançadas (Opcional):**
#
# Desenvolvedor pensando sobre: Crie um projeto de software baseado na seguinte descrição: Desenvolver um script de calculadora para ser executado no terminal...
# Desenvolvedor: Tudo bem, vamos criar um script de calculadora em Python para ser executado no terminal. Aqui está o projeto, incluindo o código e uma explicação de como ele funciona:
#
# **1. Estrutura do Projeto**
#
# Um único arquivo Python chamado `calculadora.py` será suficiente para este projeto simples.
#
# **2. Código (calculadora.py)**
#
# ```python
# def adicionar(x, y):
#     """Adiciona dois números."""
#     return x + y
#
# def subtrair(x, y):
#     """Subtrai dois números."""
#     return x - y
#
# def multiplicar(x, y):
#     """Multiplica dois números."""
#     return x * y
#
# def dividir(x, y):
#     """Divide dois números.  Lança um erro se y for zero."""
#     if y == 0:
#         raise ValueError("Não é possível dividir por zero!")
#     return x / y
#
# def calcular_potencia(x, y):
#     """Calcula x elevado à potência de y."""
#     return x ** y
#
# def calcular_raiz_quadrada(x):
#     """Calcula a raiz quadrada de x. Lança um erro se x for negativo."""
#     if x < 0:
#         raise ValueError("Não é possível calcular a raiz quadrada de um número negativo!")
#     return x**0.5
#
# def main():
#     """Função principal que executa a calculadora."""
#
#     while True:
#         print("\nSelecione a operação:")
#         print("1. Adicionar")
#         print("2. Subtrair")
#         print("3. Multiplicar")
#         print("4. Dividir")
#         print("5. Potência")
#         print("6. Raiz Quadrada")
#         print("7. Sair")
#
#         escolha = input("Digite sua escolha (1/2/3/4/5/6/7): ")
#
#         if escolha in ('1', '2', '3', '4', '5'):
#             try:
#                 num1 = float(input("Digite o primeiro número: "))
#                 num2 = float(input("Digite o segundo número: "))
#             except ValueError:
#                 print("Entrada inválida. Por favor, digite um número.")
#                 continue
#
#             if escolha == '1':
#                 print(num1, "+", num2, "=", adicionar(num1, num2))
#
#             elif escolha == '2':
#                 print(num1, "-", num2, "=", subtrair(num1, num2))
#
#             elif escolha == '3':
#                 print(num1, "*", num2, "=", multiplicar(num1, num2))
#
#             elif escolha == '4':
#                 try:
#                     print(num1, "/", num2, "=", dividir(num1, num2))
#                 except ValueError as e:
#                     print(e)
#
#             elif escolha == '5':
#                 print(num1, "^", num2, "=", calcular_potencia(num1, num2))
#
#         elif escolha == '6':
#             try:
#                 num = float(input("Digite um número: "))
#             except ValueError:
#                 print("Entrada inválida. Por favor, digite um número.")
#                 continue
#             try:
#                 print("√", num, "=", calcular_raiz_quadrada(num))
#             except ValueError as e:
#                 print(e)
#
#         elif escolha == '7':
#             print("Saindo da calculadora.")
#             break
#         else:
#             print("Entrada inválida. Por favor, digite uma opção válida.")
#
# if __name__ == "__main__":
#     main()
# ```
#
# **3. Como Executar**
#
# 1.  **Salve:** Salve o código como `calculadora.py`.
# 2.  **Abra o Terminal/Prompt de Comando:** Navegue até o diretório onde você salvou o arquivo.
# 3.  **Execute:** Digite `python calculadora.py` e pressione Enter.
#
# **4. Explicação Detalhada**
#
# *   **Funções:**
#     *   `adicionar(x, y)`, `subtrair(x, y)`, `multiplicar(x, y)`, `dividir(x, y)`:  Realizam as operações aritméticas básicas. A função `dividir` inclui tratamento de erros para evitar divisão por zero.
#     *   `calcular_potencia(x, y)`: Calcula `x` elevado à potência `y`.
#     *   `calcular_raiz_quadrada(x)`: Calcula a raiz quadrada de `x`. Ela levanta um `ValueError` se `x` for negativo.
#     *   `main
# Redator Técnico pensando sobre: Crie um projeto de software baseado na seguinte descrição: Desenvolver um script de calculadora para ser executado no terminal...
# Redator Técnico: ## Projeto: Script de Calculadora de Terminal
#
# **1. Introdução**
#
# Este documento descreve o projeto para o desenvolvimento de um script de calculadora executável no terminal. O script permitirá que os usuários realizem operações aritméticas básicas diretamente da linha de comando, tornando-o uma ferramenta útil para cálculos rápidos e sem a necessidade de interfaces gráficas complexas.
#
# **2. Objetivos**
#
# *   Criar um script de calculadora funcional que possa ser executado em um terminal (Linux, macOS, Windows com WSL/Git Bash).
# *   Implementar as operações aritméticas básicas: adição, subtração, multiplicação e divisão.
# *   Fornecer uma interface de usuário simples e intuitiva através da linha de comando.
# *   Gerenciar erros de entrada do usuário, como divisão por zero ou entradas inválidas.
# *   Permitir que o usuário insira expressões matemáticas em um formato legível.
# *   Opcionalmente, adicionar funcionalidades mais avançadas, como suporte a parênteses, exponenciação e funções trigonométricas.
#
# **3. Público Alvo**
#
# Este script de calculadora é destinado a:
#
# *   Desenvolvedores que precisam de uma ferramenta rápida para realizar cálculos simples.
# *   Usuários que preferem a eficiência da linha de comando para tarefas básicas.
# *   Estudantes aprendendo a programar e buscando um projeto prático para desenvolver suas habilidades.
#
# **4. Funcionalidades**
#
# O script de calculadora deverá oferecer as seguintes funcionalidades:
#
# *   **Operações Aritméticas Básicas:**
#     *   Adição (+)
#     *   Subtração (-)
#     *   Multiplicação (*)
#     *   Divisão (/)
# *   **Entrada do Usuário:**
#     *   O usuário deverá ser capaz de inserir expressões matemáticas através da linha de comando.
#     *   A entrada deverá ser formatada de forma clara e legível (ex: `2 + 3`, `10 / 2`).
# *   **Validação da Entrada:**
#     *   O script deverá validar a entrada do usuário para garantir que seja uma expressão matemática válida.
#     *   O script deverá lidar com erros como divisão por zero e caracteres inválidos na entrada.
# *   **Saída:**
#     *   O script deverá exibir o resultado da expressão matemática calculada no terminal.
#     *   Em caso de erro, o script deverá exibir uma mensagem de erro clara e informativa.
# *   **Opcional (Funcionalidades Avançadas):**
#     *   Suporte a parênteses para controlar a ordem das operações.
#     *   Exponenciação (^)
#     *   Funções trigonométricas (seno, cosseno, tangente).
#     *   Memória (armazenar resultados anteriores).
#
# **5. Design e Arquitetura**
#
# O script pode ser estruturado da seguinte forma:
#
# *   **Função Principal (main):**
#     *   Responsável por receber a entrada do usuário, chamar as funções apropriadas para calcular o resultado e exibir a saída.
# *   **Função de Validação da Entrada:**
#     *   Responsável por verificar se a entrada do usuário é uma expressão matemática válida.
#     *   Pode usar expressões regulares ou outras técnicas para validar a entrada.
# *   **Função de Cálculo:**
#     *   Responsável por realizar os cálculos matemáticos.
#     *   Pode usar bibliotecas matemáticas padrão da linguagem de programação escolhida.
#     *   Pode ser dividida em sub-funções para lidar com diferentes operações.
# *   **Função de Tratamento de Erros:**
#     *   Responsável por lidar com erros que ocorrem durante a execução do script.
#     *   Exibe mensagens de erro claras e informativas para o usuário.
#
# **6. Linguagem de Programação**
#
# A escolha da linguagem de programação é flexível e depende da familiaridade do desenvolvedor e das necessidades do projeto. Algumas opções populares incluem:
#
# *   **Python:** Uma linguagem de script popular com uma sintaxe clara e bibliotecas matemáticas abrangentes.
# *   **JavaScript (Node.js):** Permite criar um script de calculadora executável no terminal usando JavaScript.
# *   **Bash:** Uma linguagem de script padrão em sistemas Linux e macOS. Adequada para scripts simples, mas pode ser mais complexa para funcionalidades avançadas.
# *   **Go:** Uma linguagem eficiente e moderna com boa performance.
#
# **7. Ferramentas e Tecnologias**
#
# *   **Editor de Texto/IDE:** Visual Studio Code, Sublime Text, Atom, etc.
# *   **Terminal:** Terminal padrão do sistema operacional (Linux, macOS, Windows com WSL/Git Bash).
# *   **Gerenciador de Versões (Opcional):** Git para controle de versão do código.
#
# **8
#
# Sintetizador de Projeto consolidando...
# Sintetizador de Projeto (Síntese): OK. Com base no trabalho consolidado dos diferentes agentes, aqui está o projeto final para o script de calculadora de terminal, juntamente com a estrutura do repositório:
#
# ## Projeto Final: Script de Calculadora de Terminal
#
# **1. Visão Geral:**
#
# Este projeto consiste em criar um script de calculadora interativa que roda no terminal.  Ele permitirá que os usuários realizem operações aritméticas diretamente da linha de comando. O foco está na usabilidade, precisão, robustez e extensibilidade.
#
# **2. Objetivos:**
#
# *   Implementar operações aritméticas básicas (adição, subtração, multiplicação, divisão).
# *   Criar uma interface de usuário simples e intuitiva no terminal.
# *   Garantir a precisão dos cálculos.
# *   Lidar com entradas inválidas de forma elegante e evitar erros.
# *   Projetar o script para facilitar a adição de novas funcionalidades no futuro.
# *   Garantir a compatibilidade com diferentes sistemas operacionais (Windows, Linux, macOS).
# *   Implementar testes unitários para garantir a qualidade do código.
#
# **3. Público-Alvo:**
#
# *   Desenvolvedores que precisam de uma ferramenta rápida para cálculos simples.
# *   Usuários que preferem a eficiência da linha de comando para tarefas básicas.
# *   Estudantes aprendendo a programar e buscando um projeto prático para desenvolver suas habilidades.
#
# **4. Requisitos Funcionais:**
#
# *   **Entrada do Usuário:**
#     *   Solicitar ao usuário que insira uma expressão matemática.
#     *   Permitir números inteiros e decimais.
#     *   Suportar operadores: `+`, `-`, `*`, `/`.
#     *   Permitir parênteses `(` e `)` para agrupar operações.
#     *   Usar a tecla `Enter` para submeter a expressão.
#     *   Permitir sair do programa digitando um comando específico (ex: `sair`, `exit`, `q`).
# *   **Processamento:**
#     *   Analisar a expressão inserida.
#     *   Seguir a ordem de precedência dos operadores (parênteses, multiplicação/divisão, adição/subtração).
#     *   Realizar os cálculos corretamente.
# *   **Saída:**
#     *   Exibir o resultado do cálculo no terminal.
#     *   Exibir mensagens de erro claras em caso de entrada inválida ou erros de cálculo (ex: divisão por zero).
#     *   Exibir um prompt para a próxima expressão.
# *   **Operações Suportadas (Mínimo):**
#     *   Adição (+)
#     *   Subtração (-)
#     *   Multiplicação (*)
#     *   Divisão (/)
# *   **Operações Suportadas (Opcional - para versões futuras):**
#     *   Exponenciação (^)
#     *   Raiz Quadrada (sqrt)
#     *   Funções trigonométricas (sin, cos, tan)
#     *   Logaritmo (log)
#     *   Porcentagem (%)
#
# **5. Requisitos Não Funcionais:**
#
# *   **Performance:** Cálculos rápidos (tempo de resposta aceitável).
# *   **Usabilidade:** Interface intuitiva e fácil de usar.
# *   **Manutenibilidade:** Código bem estruturado, comentado e fácil de entender.
# *   **Portabilidade:** Compatível com Windows, Linux e macOS.
# *   **Segurança:** Evitar vulnerabilidades.
# *   **Testabilidade:** Implementar testes unitários para garantir a qualidade do código.
#
# **6. Arquitetura:**
#
# A arquitetura será modular, focada na legibilidade e manutenibilidade:
#
# *   **Entrada (Input):** Receber a entrada do usuário e validá-la.
# *   **Processamento (Calculation):** Realizar os cálculos matemáticos.
# *   **Saída (Output):** Exibir o resultado para o usuário.
# *   **Interface do Usuário (UI - Terminal):** Interagir com o usuário, apresentar opções e exibir resultados.
#
# ```
# +---------------------+     +------------------------+     +---------------------+
# | Entrada (Input)     | --> | Processamento (Calculation)| --> | Saída (Output)     |
# |  - Obter dados      |     |  - Validar operações   |     |  - Exibir resultado  |
# |  - Validar dados    |     |  - Realizar cálculos    |     |                     |
# +---------------------+     +------------------------+     +---------------------+
#        ^                                                              |
#        |                                                              |
#        +---------------------+                                       |
#        | Interface do Usuário| <---------------------------------------
#        |  - Menu/Prompt      |

# %%
print("\n--- Projeto Final ---")
print("\nCódigo:")
print(str(final_code))
# Out:
# --- Projeto Final ---
#
# Código:
# ```python
# import math
# import re
#
# class InvalidExpressionError(Exception):
#     """Exceção para expressões inválidas."""
#     pass
#
# def evaluate_expression(expression):
#     """
#     Avalia uma expressão matemática.
#
#     Args:
#         expression: A expressão matemática como uma string.
#
#     Returns:
#         O resultado da expressão como um float.
#
#     Raises:
#         InvalidExpressionError: Se a expressão for inválida.
#         ZeroDivisionError: Se houver uma divisão por zero.
#     """
#
#     try:
#         # Remove espaços em branco
#         expression = expression.replace(" ", "")
#
#         # Validação básica para evitar eval() perigoso.  Mais validação é feita posteriormente.
#         if not re.match(r"^[\d\+\-\*\/\(\)\.\s]+$", expression):
#             raise InvalidExpressionError("Expressão contém caracteres inválidos.")
#
#         # Substitui sqrt por math.sqrt para avaliação segura
#         expression = re.sub(r"sqrt\((.*?)\)", r"math.sqrt(\1)", expression)
#
#         # Avalia a expressão usando eval (com precauções)
#         result = eval(expression, {"math": math}, {})  # Passa math como um namespace seguro
#
#         if not isinstance(result, (int, float)):
#             raise InvalidExpressionError("Expressão inválida.")
#
#         return float(result)
#
#     except (SyntaxError, NameError, TypeError) as e:
#         raise InvalidExpressionError(f"Erro de sintaxe ou tipo: {e}")
#     except ZeroDivisionError:
#         raise ZeroDivisionError("Divisão por zero!")
#     except Exception as e:
#         raise InvalidExpressionError(f"Erro desconhecido: {e}")
#
#
# def get_user_input():
#     """
#     Obtém a entrada do usuário.
#
#     Returns:
#         A expressão inserida pelo usuário como uma string.
#     """
#     return input("Digite uma expressão (ou 'sair' para sair): ")
#
#
# def main():
#     """
#     Função principal do script da calculadora.
#     """
#     print("Calculadora de Terminal")
#     print("Digite 'sair' para sair.")
#
#     while True:
#         expression = get_user_input()
#
#         if expression.lower() == 'sair':
#             print("Saindo...")
#             break
#
#         try:
#             result = evaluate_expression(expression)
#             print("Resultado:", result)
#         except InvalidExpressionError as e:
#             print("Erro:", e)
#         except ZeroDivisionError as e:
#             print("Erro:", e)
#         except Exception as e:
#             print(f"Um erro inesperado ocorreu: {e}")
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# **Explicação do Código:**
#
# 1.  **Importação de Módulos:**
#     *   `math`: Para funções matemáticas como `sqrt`.
#     *   `re`: Para expressões regulares, usadas na validação e substituição de strings.
#
# 2.  **`InvalidExpressionError` Exception:**
#     *   Uma exceção personalizada para indicar que a expressão inserida é inválida. Isso melhora a clareza e o tratamento de erros.
#
# 3.  **`evaluate_expression(expression)` Function:**
#     *   Recebe a expressão como uma string.
#     *   **Limpeza da Entrada:** Remove espaços em branco para facilitar a análise.
#     *   **Validação:** Usa uma expressão regular (`re.match`) para verificar se a expressão contém apenas caracteres permitidos (dígitos, operadores, parênteses, ponto decimal e espaços em branco). Essa é uma medida de segurança importante para evitar a execução de código arbitrário através da função `eval()`.
#     *   **Substituição de Funções:** Substitui `sqrt(...)` por `math.sqrt(...)` para permitir o uso da função raiz quadrada do módulo `math` de forma segura.
#     *   **Avaliação com `eval()`:** Usa a função `eval()` para avaliar a expressão.
#         *   **Segurança com `eval()`:**  Passa um dicionário `{"math": math}` como o segundo argumento para `eval()`. Isso cria um namespace seguro, permitindo apenas o acesso às funções e constantes do módulo `math`. O terceiro argumento `{}` garante que nenhuma variável local esteja acessível durante a avaliação.
#     *   **Verificação do Tipo de Resultado:** Garante que o resultado da avaliação seja um número (int ou float).
#     *   **Tratamento de Erros:** Usa blocos `try...except` para capturar possíveis erros durante a avaliação:
#         *   `SyntaxError`, `NameError`, `TypeError`:  Ind

# %%
print("\nDocumentação:")
print(str(final_documentation))
# Out:
# Documentação:
# OK. Aqui está a documentação técnica para o projeto de script de calculadora de terminal, com base nas informações fornecidas.
#
# # Documentação Técnica: Script de Calculadora de Terminal
#
# ## 1. Introdução
#
# Este documento fornece uma descrição técnica detalhada do script de calculadora de terminal. Ele aborda a arquitetura, o design, a implementação e o uso do script.  O objetivo é fornecer informações suficientes para desenvolvedores que desejam entender, modificar ou estender a funcionalidade da calculadora.
#
# ## 2. Visão Geral
#
# O script de calculadora de terminal é uma aplicação de linha de comando que permite aos usuários realizar operações aritméticas diretamente no terminal. Ele oferece uma interface simples e intuitiva para inserir expressões matemáticas e exibir os resultados. O script foi projetado com foco na precisão, robustez, manutenibilidade e extensibilidade.
#
# ## 3. Arquitetura
#
# O script segue uma arquitetura modular, dividida em três componentes principais:
#
# *   **Entrada (Input):** Responsável por receber a expressão matemática do usuário e realizar uma validação inicial.
# *   **Processamento (Calculation):** Responsável por analisar a expressão, realizar os cálculos e tratar possíveis erros.
# *   **Saída (Output):** Responsável por exibir o resultado do cálculo ou mensagens de erro para o usuário.
#
# Esses componentes interagem da seguinte forma:
#
# ```
# +---------------------+     +------------------------+     +---------------------+
# | Entrada (Input)     | --> | Processamento (Calculation)| --> | Saída (Output)     |
# |  - Obter dados      |     |  - Validar operações   |     |  - Exibir resultado  |
# |  - Validar dados    |     |  - Realizar cálculos    |     |                     |
# +---------------------+     +------------------------+     +---------------------+
#        ^                                                              |
#        |                                                              |
#        +---------------------+                                       |
#        | Interface do Usuário| <---------------------------------------
#        |  - Menu/Prompt      |
# ```
#
# ## 4. Design
#
# ### 4.1. Componentes
#
# *   **Entrada:**
#     *   Função `get_user_input()`: Solicita ao usuário que insira uma expressão e retorna a entrada como uma string.
#     *   Validação inicial: Remove espaços em branco. A validação mais completa é realizada no componente de processamento.
# *   **Processamento:**
#     *   Função `evaluate_expression(expression)`: Recebe a expressão como uma string, valida-a e calcula o resultado.
#         *   Validação: Utiliza expressões regulares para garantir que a expressão contenha apenas caracteres válidos (dígitos, operadores, parênteses, ponto decimal).
#         *   Substituição de Funções: Substitui `sqrt(...)` por `math.sqrt(...)` para permitir o uso seguro da função raiz quadrada.
#         *   Avaliação: Utiliza a função `eval()` para avaliar a expressão. Um namespace seguro é criado para limitar o acesso a funções e variáveis externas.
#         *   Tratamento de Erros: Captura e trata `SyntaxError`, `NameError`, `TypeError`, `ZeroDivisionError` e outras exceções para fornecer mensagens de erro informativas ao usuário.
# *   **Saída:**
#     *   A função `main()` exibe o resultado do cálculo ou mensagens de erro no terminal.
#
# ### 4.2. Estruturas de Dados
#
# *   **String:** A entrada do usuário é armazenada como uma string.
# *   **Float:** O resultado do cálculo é retornado como um float.
#
# ### 4.3. Tratamento de Erros
#
# O script implementa um tratamento de erros robusto para lidar com entradas inválidas e erros de cálculo. As seguintes exceções são tratadas:
#
# *   `InvalidExpressionError`: Exceção personalizada para expressões inválidas.
# *   `SyntaxError`: Erro de sintaxe na expressão.
# *   `NameError`: Nome inválido na expressão.
# *   `TypeError`: Erro de tipo na expressão.
# *   `ZeroDivisionError`: Divisão por zero.
# *   Outras exceções inesperadas são capturadas e exibidas com uma mensagem de erro genérica.
#
# ## 5. Implementação
#
# O script é implementado em Python 3.
#
# ### 5.1. Estrutura do Código
#
# ```python
# import math
# import re
#
# class InvalidExpressionError(Exception):
#     """Exceção para expressões inválidas."""
#     pass
#
# def evaluate_expression(expression):
#     """
#     Avalia uma expressão matemática.
#     """
#     # ... (código da função) ...
#
# def get_user_input():
#     """
#     Obtém a entrada do usuário.
